# %% [markdown]
# ## Keras model - DenseNet
# ----
#
# * **features**
#
# > **DenseNet implementation**
# > -  Three Dense block
# > - change loss function  :  MSE, MAE  $\rightarrow$ Logcosh

# %%
import numpy as np 
import pickle 

# load dataset 
# with open('../sample_image/sample560_crop_df.bin', 'rb') as f :
#     crop_img = pickle.load(f)

with open('../sample_image/final_df.bin', 'rb') as f :
    crop_img = pickle.load(f)

    
# X = np.array([i for i in crop_img.crop_img_03])
X = np.array([i for i in crop_img.crop_images])
y = crop_img.weight.values

idx = list(np.random.choice(range(len(X)), int(len(X) * 0.8), replace=False))
test_idx = list(set(list(range(len(X)))) - set(idx))

X_train = X[idx]
y_train = y[idx]

X_test = X[test_idx]
y_test = y[test_idx]

# %%
X.shape
# Out:
# (560, 250, 550, 3)

# %% [markdown]
# ### Parameters

# %%
BATCH_SIZE = 24 
LOSS = "mean_squared_error"
OPTIMIZER = ["adagrad", "adadelta", "adam", "adamax", "rmsprob"]

# %% [markdown]
# ### Model Architecture

# %%
from keras.models import Sequential
from keras.layers.core import Dense
from keras.optimizers import SGD
from keras.engine.input_layer import Input
from keras.models import Model
from keras import regularizers 
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Concatenate, AveragePooling2D, GlobalAveragePooling2D, Activation, concatenate
from keras.regularizers import l2


def DenseNet():
    
    inputs = Input(shape=(250, 550, 3))
    
    conv_1 = Conv2D(16, (7, 7), strides=2, padding='same')(inputs)
    act_1 = Activation('relu')(conv_1)
    max_pool = MaxPooling2D(pool_size=(3, 3), strides=2, padding='same')(act_1)
    
    ##### DENSE BLOCK 1 #####
    
#     bn_1 = BatchNormalization()(max_pool)
    conv_1 = Conv2D(32, (1, 1), padding='same')(max_pool)
    act_1 = Activation('relu')(conv_1)
#     bn_2 = BatchNormalization()(act_1)
    conv_2 = Conv2D(8, (3, 3), padding='same')(act_1)
    act_2 = Activation('relu')(conv_2)
    merged_1 =concatenate([act_2, max_pool], axis=-1)
    
#     bn_1 = BatchNormalization()(merged_1)
    conv_1 = Conv2D(32, (1, 1), padding='same')(merged_1)
    act_1 = Activation('relu')(conv_1)
#     bn_2 = BatchNormalization()(act_1)
    conv_2 = Conv2D(8, (3, 3), padding='same')(act_1)
    act_2 = Activation('relu')(conv_2)
    merged_2 =concatenate([act_2, merged_1], axis=-1)
    
#     bn_1 = BatchNormalization()(merged_2)
    conv_1 = Conv2D(32, (1, 1), padding='same')(merged_2)
    act_1 = Activation('relu')(conv_1)
#     bn_2 = BatchNormalization()(act_1)
    conv_2 = Conv2D(8, (3, 3), padding='same')(act_1)
    act_2 = Activation('relu')(conv_2)
    merged_3 =concatenate([act_2, merged_2], axis=-1)
    
#     bn_1 = BatchNormalization()(merged_3)
    conv_1 = Conv2D(32, (1, 1), padding='same')(merged_3)
    act_1 = Activation('relu')(conv_1)
#     bn_2 = BatchNormalization()(act_1)
    conv_2 = Conv2D(8, (3, 3), padding='same')(act_1)
    act_2 = Activation('relu')(conv_2)
    merged_4 =concatenate([act_2, merged_3], axis=-1)
    
    ###### Transition layer 1 #####

    conv_1 = Conv2D(32, (1, 1), padding='same')(merged_4)
    act_1 = Activation('relu')(conv_1)
    avg_p_1 = AveragePooling2D(strides=2)(act_1)
    
    
    ##### DENSE BLOCK 2 #####
    
    #     bn_1 = BatchNormalization()(max_pool)
    conv_1 = Conv2D(32, (1, 1), padding='same')(avg_p_1)
    act_1 = Activation('relu')(conv_1)
#     bn_2 = BatchNormalization()(act_1)
    conv_2 = Conv2D(8, (3, 3), padding='same')(act_1)
    act_2 = Activation('relu')(conv_2)
    merged_1 =concatenate([act_2, avg_p_1], axis=-1)
    
#     bn_1 = BatchNormalization()(merged_1)
    conv_1 = Conv2D(32, (1, 1), padding='same')(merged_1)
    act_1 = Activation('relu')(conv_1)
#     bn_2 = BatchNormalization()(act_1)
    conv_2 = Conv2D(8, (3, 3), padding='same')(act_1)
    act_2 = Activation('relu')(conv_2)
    merged_2 =concatenate([act_2, merged_1], axis=-1)
    
#     bn_1 = BatchNormalization()(merged_2)
    conv_1 = Conv2D(32, (1, 1), padding='same')(merged_2)
    act_1 = Activation('relu')(conv_1)
#     bn_2 = BatchNormalization()(act_1)
    conv_2 = Conv2D(8, (3, 3), padding='same')(act_1)
    act_2 = Activation('relu')(conv_2)
    merged_3 =concatenate([act_2, merged_2], axis=-1)
    
#     bn_1 = BatchNormalization()(merged_3)
    conv_1 = Conv2D(32, (1, 1), padding='same')(merged_3)
    act_1 = Activation('relu')(conv_1)
#     bn_2 = BatchNormalization()(act_1)
    conv_2 = Conv2D(8, (3, 3), padding='same')(act_1)
    act_2 = Activation('relu')(conv_2)
    merged_4 =concatenate([act_2, merged_3], axis=-1)
    
#     ###### Transition layer 1 #####

#     conv_1 = Conv2D(32, (1, 1), padding='same')(merged_4)
#     act_1 = Activation('relu')(conv_1)
#     avg_p_1 = AveragePooling2D(strides=2)(act_1)
    
#     ###### Transition layer 2 #####

#     conv_1 = Conv2D(32, (1, 1), padding='same')(merged_4)
#     act_1 = Activation('relu')(conv_1)
#     avg_p_1 = AveragePooling2D(strides=2)(act_1)
    
    
#     ##### DENSE BLOCK 3 #####
    
#     bn_1 = BatchNormalization()(avg_p_1)
#     conv_1 = Conv2D(32, (1, 1), padding='same')(bn_1)
#     act_1 = Activation('relu')(conv_1)
#     bn_2 = BatchNormalization()(act_1)
#     conv_2 = Conv2D(8, (3, 3), padding='same')(bn_2)
#     act_2 = Activation('relu')(conv_2)
#     merged_1 =concatenate([act_2, avg_p_1], axis=-1)
    
#     bn_1 = BatchNormalization()(merged_1)
#     conv_1 = Conv2D(32, (1, 1), padding='same')(bn_1)
#     act_1 = Activation('relu')(conv_1)
#     bn_2 = BatchNormalization()(act_1)
#     conv_2 = Conv2D(8, (3, 3), padding='same')(bn_2)
#     act_2 = Activation('relu')(conv_2)
#     merged_2 =concatenate([act_2, merged_1], axis=-1)
    
#     bn_1 = BatchNormalization()(merged_2)
#     conv_1 = Conv2D(32, (1, 1), padding='same')(bn_1)
#     act_1 = Activation('relu')(conv_1)
#     bn_2 = BatchNormalization()(act_1)
#     conv_2 = Conv2D(8, (3, 3), padding='same')(bn_2)
#     act_2 = Activation('relu')(conv_2)
#     merged_3 =concatenate([act_2, merged_2], axis=-1)
    
#     bn_1 = BatchNormalization()(merged_3)
#     conv_1 = Conv2D(32, (1, 1), padding='same')(bn_1)
#     act_1 = Activation('relu')(conv_1)
#     bn_2 = BatchNormalization()(act_1)
#     conv_2 = Conv2D(8, (3, 3), padding='same')(bn_2)
#     act_2 = Activation('relu')(conv_2)
#     merged_4 =concatenate([act_2, merged_3], axis=-1)
    
    ## Dense Layer with GlobalAveragePooling
    
    global_avg_p = GlobalAveragePooling2D()(merged_4)
    denselayer = Dense(100, activation='elu', kernel_regularizer=l2(0.001))(global_avg_p)
    output = Dense(1)(denselayer)
    
    
    model = Model(inputs=[inputs], outputs=[output])
        
    return model

# %%
from keras.utils.training_utils import multi_gpu_model
from keras.optimizers import Adam
from keras import losses

model = DenseNet()
op = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-10, decay=0.008, amsgrad=False)
model = multi_gpu_model(model, gpus=2)

## loss func : Mean squared error --> mean absoulute error 
model.compile(loss=losses.logcosh, optimizer=op, metrics=['mae'])

# %%
# %%time
hist = model.fit(X_train, y_train, epochs=51, batch_size=24, validation_data=(X_test, y_test), verbose=2)
# Out:
# Train on 448 samples, validate on 112 samples
# Epoch 1/51
#  - 15s - loss: 33.8355 - mean_absolute_error: 34.4395 - val_loss: 13.1252 - val_mean_absolute_error: 13.7338
# Epoch 2/51
#  - 3s - loss: 14.2160 - mean_absolute_error: 14.8268 - val_loss: 12.5705 - val_mean_absolute_error: 13.1871
# Epoch 3/51
#  - 3s - loss: 13.3162 - mean_absolute_error: 13.9333 - val_loss: 12.0516 - val_mean_absolute_error: 12.6692
# Epoch 4/51
#  - 3s - loss: 12.6987 - mean_absolute_error: 13.3190 - val_loss: 9.8997 - val_mean_absolute_error: 10.5171
# Epoch 5/51
#  - 3s - loss: 9.9355 - mean_absolute_error: 10.5486 - val_loss: 7.5202 - val_mean_absolute_error: 8.1268
# Epoch 6/51
#  - 3s - loss: 10.2501 - mean_absolute_error: 10.8556 - val_loss: 12.8084 - val_mean_absolute_error: 13.4335
# Epoch 7/51
#  - 3s - loss: 10.2636 - mean_absolute_error: 10.8654 - val_loss: 7.1662 - val_mean_absolute_error: 7.7654
# Epoch 8/51
#  - 3s - loss: 8.0479 - mean_absolute_error: 8.6545 - val_loss: 7.3154 - val_mean_absolute_error: 7.9137
# Epoch 9/51
#  - 3s - loss: 7.5179 - mean_absolute_error: 8.1177 - val_loss: 7.2104 - val_mean_absolute_error: 7.7971
# Epoch 10/51
#  - 3s - loss: 7.9690 - mean_absolute_error: 8.5761 - val_loss: 6.3500 - val_mean_absolute_error: 6.9507
# Epoch 11/51
#  - 3s - loss: 7.0256 - mean_absolute_error: 7.6127 - val_loss: 7.3431 - val_mean_absolute_error: 7.9416
# Epoch 12/51
#  - 3s - loss: 7.2205 - mean_absolute_error: 7.8216 - val_loss: 5.9277 - val_mean_absolute_error: 6.5243
# Epoch 13/51
#  - 3s - loss: 6.7082 - mean_absolute_error: 7.3028 - val_loss: 6.0566 - val_mean_absolute_error: 6.6463
# Epoch 14/51
#  - 3s - loss: 6.6451 - mean_absolute_error: 7.2415 - val_loss: 5.9104 - val_mean_absolute_error: 6.4743
# Epoch 15/51
#  - 3s - loss: 6.3350 - mean_absolute_error: 6.9328 - val_loss: 5.8420 - val_mean_absolute_error: 6.4370
# Epoch 16/51
#  - 3s - loss: 6.3152 - mean_absolute_error: 6.9198 - val_loss: 5.5834 - val_mean_absolute_error: 6.1527
# Epoch 17/51
#  - 3s - loss: 6.2442 - mean_absolute_error: 6.8441 - val_loss: 5.7839 - val_mean_absolute_error: 6.3878
# Epoch 18/51
#  - 3s - loss: 5.8612 - mean_absolute_error: 6.4589 - val_loss: 5.4607 - val_mean_absolute_error: 6.0614
# Epoch 19/51
#  - 3s - loss: 5.7560 - mean_absolute_error: 6.3552 - val_loss: 5.9309 - val_mean_absolute_error: 6.5519
# Epoch 20/51
#  - 3s - loss: 5.8268 - mean_absolute_error: 6.4286 - val_loss: 6.4611 - val_mean_absolute_error: 7.0809
# Epoch 21/51
#  - 3s - loss: 5.5206 - mean_absolute_error: 6.1154 - val_loss: 5.1446 - val_mean_absolute_error: 5.7458
# Epoch 22/51
#  - 3s - loss: 5.0223 - mean_absolute_error: 5.6100 - val_loss: 4.6763 - val_mean_absolute_error: 5.2522
# Epoch 23/51
#  - 3s - loss: 4.8882 - mean_absolute_error: 5.4791 - val_loss: 4.5458 - val_mean_absolute_error: 5.1359
# Epoch 24/51
#  - 4s - loss: 4.8980 - mean_absolute_error: 5.4804 - val_loss: 4.8258 - val_mean_absolute_error: 5.4161
# Epoch 25/51
#  - 3s - loss: 5.1154 - mean_absolute_error: 5.7135 - val_loss: 4.2184 - val_mean_absolute_error: 4.8014
# Epoch 26/51
#  - 3s - loss: 4.8472 - mean_absolute_error: 5.4460 - val_loss: 4.6032 - val_mean_absolute_error: 5.1949
# Epoch 27/51
#  - 3s - loss: 4.4631 - mean_absolute_error: 5.0462 - val_loss: 4.3194 - val_mean_absolute_error: 4.8983
# Epoch 28/51
#  - 3s - loss: 4.1818 - mean_absolute_error: 4.7662 - val_loss: 4.0894 - val_mean_absolute_error: 4.6769
# Epoch 29/51
#  - 3s - loss: 4.1020 - mean_absolute_error: 4.6900 - val_loss: 4.1596 - val_mean_absolute_error: 4.7378
# Epoch 30/51
#  - 3s - loss: 4.0343 - mean_absolute_error: 4.6112 - val_loss: 4.2386 - val_mean_absolute_error: 4.8249
# Epoch 31/51
#  - 3s - loss: 4.2384 - mean_absolute_error: 4.8316 - val_loss: 4.7498 - val_mean_absolute_error: 5.3427
# Epoch 32/51
#  - 3s - loss: 4.1085 - mean_absolute_error: 4.6920 - val_loss: 4.7410 - val_mean_absolute_error: 5.3432
# Epoch 33/51
#  - 3s - loss: 4.4710 - mean_absolute_error: 5.0573 - val_loss: 3.8570 - val_mean_absolute_error: 4.4226
# Epoch 34/51
#  - 3s - loss: 4.0974 - mean_absolute_error: 4.6778 - val_loss: 3.7682 - val_mean_absolute_error: 4.3410
# Epoch 35/51
#  - 3s - loss: 3.8058 - mean_absolute_error: 4.3855 - val_loss: 3.8540 - val_mean_absolute_error: 4.4346
# Epoch 36/51
#  - 3s - loss: 3.6878 - mean_absolute_error: 4.2653 - val_loss: 3.8412 - val_mean_absolute_error: 4.4383
# Epoch 37/51
#  - 4s - loss: 3.5895 - mean_absolute_error: 4.1613 - val_loss: 3.9209 - val_mean_absolute_error: 4.5015
# Epoch 38/51
#  - 4s - loss: 3.7980 - mean_absolute_error: 4.3748 - val_loss: 3.5840 - val_mean_absolute_error: 4.1371
# Epoch 39/51
#  - 4s - loss: 3.5637 - mean_absolute_error: 4.1380 - val_loss: 3.8651 - val_mean_absolute_error: 4.4684
# Epoch 40/51
#  - 4s - loss: 3.5536 - mean_absolute_error: 4.1233 - val_loss: 3.6865 - val_mean_absolute_error: 4.2771
# Epoch 41/51
#  - 4s - loss: 3.6892 - mean_absolute_error: 4.2697 - val_loss: 3.6475 - val_mean_absolute_error: 4.2244
# Epoch 42/51
#  - 4s - loss: 3.5566 - mean_absolute_error: 4.1199 - val_loss: 3.5837 - val_mean_absolute_error: 4.1690
# Epoch 43/51
#  - 4s - loss: 3.4045 - mean_absolute_error: 3.9799 - val_loss: 3.7399 - val_mean_absolute_error: 4.3286
# Epoch 44/51
#  - 4s - loss: 3.4100 - mean_absolute_error: 3.9784 - val_loss: 3.5910 - val_mean_absolute_error: 4.1783
# Epoch 45/51
#  - 4s - loss: 3.4941 - mean_absolute_error: 4.0646 - val_loss: 3.5628 - val_mean_absolute_error: 4.1526
# Epoch 46/51
#  - 4s - loss: 3.3815 - mean_absolute_error: 3.9528 - val_loss: 3.6488 - val_mean_absolute_error: 4.2270
# Epoch 47/51
#  - 4s - loss: 3.6003 - mean_absolute_error: 4.1733 - val_loss: 3.9461 - val_mean_absolute_error: 4.5259
# Epoch 48/51
#  - 4s - loss: 3.5595 - mean_absolute_error: 4.1358 - val_loss: 3.6044 - val_mean_absolute_error: 4.1825
# Epoch 49/51
#  - 4s - loss: 3.5469 - mean_absolute_error: 4.1311 - val_loss: 3.5190 - val_mean_absolute_error: 4.1073
# Epoch 50/51
#  - 3s - loss: 3.4495 - mean_absolute_error: 4.0270 - val_loss: 3.3783 - val_mean_absolute_error: 3.9466
# Epoch 51/51
#  - 4s - loss: 3.4027 - mean_absolute_error: 3.9743 - val_loss: 3.5765 - val_mean_absolute_error: 4.1647
# CPU times: user 2min 18s, sys: 1min 7s, total: 3min 26s
# Wall time: 3min 7s

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(13,13))
plt.plot(hist.history["loss"])
plt.plot(hist.history["val_loss"])
plt.legend(["loss","val_loss" ])
plt.show()

# %%
pred = model.predict(X_test)
for i, j in zip(pred, y_test):
    print("prediction : {}, Truth : {} ".format(i, j))
# Out:
# prediction : [96.99013], Truth : 95.69
# prediction : [126.64892], Truth : 124.51
# prediction : [126.520874], Truth : 125.38
# prediction : [94.710945], Truth : 92.77
# prediction : [115.58733], Truth : 125.53
# prediction : [97.101395], Truth : 91.66
# prediction : [126.84363], Truth : 128.98
# prediction : [113.69842], Truth : 120.29
# prediction : [123.84396], Truth : 122.88
# prediction : [96.65738], Truth : 93.89
# prediction : [124.48039], Truth : 129.03
# prediction : [127.08376], Truth : 128.82
# prediction : [126.6682], Truth : 126.05
# prediction : [126.78036], Truth : 128.0
# prediction : [121.111786], Truth : 120.34
# prediction : [96.89235], Truth : 96.27
# prediction : [124.79469], Truth : 124.27
# prediction : [125.384094], Truth : 120.82
# prediction : [123.15028], Truth : 121.72
# prediction : [95.34826], Truth : 96.7
# prediction : [95.05395], Truth : 91.35
# prediction : [94.84937], Truth : 92.98
# prediction : [94.381454], Truth : 99.25
# prediction : [95.061295], Truth : 99.67
# prediction : [96.82121], Truth : 91.46
# prediction : [94.90587], Truth : 94.13
# prediction : [97.08717], Truth : 95.26
# prediction : [94.24173], Truth : 98.18
# prediction : [95.04561], Truth : 97.32
# prediction : [95.3512], Truth : 95.76
# prediction : [95.22809], Truth : 92.1
# prediction : [94.747986], Truth : 95.46
# prediction : [96.59431], Truth : 99.25
# prediction : [97.31259], Truth : 94.42
# prediction : [95.23714], Truth : 90.76
# prediction : [96.99089], Truth : 96.26
# prediction : [94.25486], Truth : 93.9
# prediction : [95.22347], Truth : 91.3
# prediction : [96.4864], Truth : 94.84
# prediction : [105.94202], Truth : 102.3
# prediction : [104.61336], Truth : 100.68
# prediction : [104.84524], Truth : 101.86
# prediction : [107.21411], Truth : 107.83
# prediction : [107.32732], Truth : 109.35
# prediction : [105.07995], Truth : 101.69
# prediction : [105.02583], Truth : 102.71
# prediction : [105.64191], Truth : 109.71
# prediction : [105.25322], Truth : 106.77
# prediction : [104.9555], Truth : 104.84
# prediction : [105.934204], Truth : 107.62
# prediction : [105.76719], Truth : 106.4
# prediction : [105.62054], Truth : 101.2
# prediction : [105.468765], Truth : 108.11
# prediction : [107.72856], Truth : 109.28
# prediction : [108.14666], Truth : 105.45
# prediction : [104.92568], Truth : 103.83
# prediction : [105.21535], Truth : 100.69
# prediction : [106.167336], Truth : 108.17
# prediction : [107.841194], Truth : 103.13
# prediction : [105.449135], Truth : 102.35
# prediction : [107.26667], Truth : 102.94
# prediction : [103.87693], Truth : 102.48
# prediction : [113.47989], Truth : 116.01
# prediction : [115.74674], Truth : 112.6
# prediction : [114.22382], Truth : 111.9
# prediction : [114.29386], Truth : 113.76
# prediction : [115.651436], Truth : 110.68
# prediction : [114.73796], Truth : 111.41
# prediction : [112.430466], Truth : 111.53
# prediction : [115.02127], Truth : 116.87
# prediction : [117.636856], Truth : 118.62
# prediction : [115.351425], Truth : 118.41
# prediction : [115.2837], Truth : 115.68
# prediction : [114.742714], Truth : 116.06
# prediction : [118.87845], Truth : 119.09
# prediction : [115.96824], Truth : 113.5
# prediction : [116.184135], Truth : 116.81
# prediction : [113.635605], Truth : 110.6
# prediction : [114.61356], Truth : 114.16
# prediction : [119.11535], Truth : 119.24
# prediction : [115.011246], Truth : 114.28
# prediction : [113.46518], Truth : 111.68
# prediction : [115.54704], Truth : 112.12
# prediction : [112.08882], Truth : 113.85
# prediction : [116.50476], Truth : 118.3
# prediction : [115.22416], Truth : 114.92
# prediction : [117.18801], Truth : 113.62
# prediction : [116.86416], Truth : 115.11
# prediction : [115.61611], Truth : 119.15
# prediction : [116.307785], Truth : 114.0
# prediction : [116.6495], Truth : 111.98
# prediction : [115.474945], Truth : 115.37
# prediction : [112.49635], Truth : 114.65
# prediction : [116.30888], Truth : 114.11
# prediction : [126.11232], Truth : 129.89
# prediction : [123.83511], Truth : 129.09
# prediction : [126.67429], Truth : 127.6
# prediction : [125.059975], Truth : 121.71
# prediction : [125.8857], Truth : 121.08
# prediction : [126.55739], Truth : 126.14
# prediction : [126.30019], Truth : 127.14
# prediction : [125.77982], Truth : 122.39
# prediction : [123.86984], Truth : 126.09
# prediction : [124.23951], Truth : 124.45
# prediction : [126.064186], Truth : 123.79
# prediction : [126.75264], Truth : 124.41
# prediction : [125.3569], Truth : 126.34
# prediction : [124.8055], Truth : 121.83
# prediction : [125.671974], Truth : 122.98
# prediction : [125.24762], Truth : 125.12
# prediction : [127.44983], Truth : 125.6
# prediction : [120.64941], Truth : 123.08
