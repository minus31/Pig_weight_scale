# %% [markdown]
# ## Keras model - DenseNet
# ----
#
# * **features**
#
# > **DenseNet implementation**
# > - Two Dense block
# > - Change loss function  :  MSE, MAE  $\rightarrow$ Logcosh

# %%
import numpy as np 
import pickle 

# load dataset 
# with open('../sample_image/sample560_crop_df.bin', 'rb') as f :
#     crop_img = pickle.load(f)

with open('../sample_image/final_df.bin', 'rb') as f :
    crop_img = pickle.load(f)

    
# X = np.array([i for i in crop_img.crop_img_03])
X = np.array([i for i in crop_img.crop_images])
y = crop_img.weight.values

idx = list(np.random.choice(range(len(X)), int(len(X) * 0.8), replace=False))
test_idx = list(set(list(range(len(X)))) - set(idx))

X_train = X[idx]
y_train = y[idx]

X_test = X[test_idx]
y_test = y[test_idx]

# %%
X.shape
# Out:
# (560, 250, 550, 3)

# %% [markdown]
# ### Parameters

# %%
BATCH_SIZE = 24 
OPTIMIZER = ["adagrad", "adadelta", "adam", "adamax", "rmsprob"]

# %% [markdown]
# ### Model Architecture

# %%
from keras.models import Sequential
from keras.layers.core import Dense
from keras.optimizers import SGD
from keras.engine.input_layer import Input
from keras.models import Model
from keras import regularizers 
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Concatenate, AveragePooling2D, GlobalAveragePooling2D, Activation, concatenate
from keras.regularizers import l2


def DenseNet():
    
    inputs = Input(shape=(250, 550, 3))
    
    conv_1 = Conv2D(16, (7, 7), strides=2, padding='same')(inputs)
    act_1 = Activation('relu')(conv_1)
    max_pool = MaxPooling2D(pool_size=(3, 3), strides=2, padding='same')(act_1)
    
    ##### DENSE BLOCK 1 #####
    
    bn_1 = BatchNormalization()(max_pool)
    conv_1 = Conv2D(32, (1, 1), padding='same')(bn_1)
    act_1 = Activation('relu')(conv_1)
    bn_2 = BatchNormalization()(act_1)
    conv_2 = Conv2D(8, (3, 3), padding='same')(bn_2)
    act_2 = Activation('relu')(conv_2)
    merged_1 = concatenate([act_2, max_pool], axis=-1)
    
    bn_1 = BatchNormalization()(merged_1)
    conv_1 = Conv2D(32, (1, 1), padding='same')(bn_1)
    act_1 = Activation('relu')(conv_1)
    bn_2 = BatchNormalization()(act_1)
    conv_2 = Conv2D(8, (3, 3), padding='same')(bn_2)
    act_2 = Activation('relu')(conv_2)
    merged_2 = concatenate([act_2, merged_1], axis=-1)
    
    bn_1 = BatchNormalization()(merged_2)
    conv_1 = Conv2D(32, (1, 1), padding='same')(bn_1)
    act_1 = Activation('relu')(conv_1)
    bn_2 = BatchNormalization()(act_1)
    conv_2 = Conv2D(8, (3, 3), padding='same')(bn_2)
    act_2 = Activation('relu')(conv_2)
    merged_3 = concatenate([act_2, merged_2], axis=-1)
    
    bn_1 = BatchNormalization()(merged_3)
    conv_1 = Conv2D(32, (1, 1), padding='same')(bn_1)
    act_1 = Activation('relu')(conv_1)
    bn_2 = BatchNormalization()(act_1)
    conv_2 = Conv2D(8, (3, 3), padding='same')(bn_2)
    act_2 = Activation('relu')(conv_2)
    merged_4 = concatenate([act_2, merged_3], axis=-1)
    
    ###### Transition layer 1 #####

    conv_1 = Conv2D(32, (1, 1), padding='same')(merged_4)
    act_1 = Activation('relu')(conv_1)
    avg_p_1 = AveragePooling2D(strides=2)(act_1)
    
    
    ##### DENSE BLOCK 2 #####
    
    bn_1 = BatchNormalization()(avg_p_1)
    conv_1 = Conv2D(32, (1, 1), padding='same')(bn_1)
    act_1 = Activation('relu')(conv_1)
    bn_2 = BatchNormalization()(act_1)
    conv_2 = Conv2D(8, (3, 3), padding='same')(bn_2)
    act_2 = Activation('relu')(conv_2)
    merged_1 = concatenate([act_2, avg_p_1], axis=-1)
    
    bn_1 = BatchNormalization()(merged_1)
    conv_1 = Conv2D(32, (1, 1), padding='same')(bn_1)
    act_1 = Activation('relu')(conv_1)
    bn_2 = BatchNormalization()(act_1)
    conv_2 = Conv2D(8, (3, 3), padding='same')(bn_2)
    act_2 = Activation('relu')(conv_2)
    merged_2 = concatenate([act_2, merged_1], axis=-1)
    
    bn_1 = BatchNormalization()(merged_2)
    conv_1 = Conv2D(32, (1, 1), padding='same')(bn_1)
    act_1 = Activation('relu')(conv_1)
    bn_2 = BatchNormalization()(act_1)
    conv_2 = Conv2D(8, (3, 3), padding='same')(bn_2)
    act_2 = Activation('relu')(conv_2)
    merged_3 = concatenate([act_2, merged_2], axis=-1)
    
    bn_1 = BatchNormalization()(merged_3)
    conv_1 = Conv2D(32, (1, 1), padding='same')(bn_1)
    act_1 = Activation('relu')(conv_1)
    bn_2 = BatchNormalization()(act_1)
    conv_2 = Conv2D(8, (3, 3), padding='same')(bn_2)
    act_2 = Activation('relu')(conv_2)
    merged_4 = concatenate([act_2, merged_3], axis=-1)
    
#     ###### Transition layer 2 #####

#     conv_1 = Conv2D(32, (1, 1), padding='same')(merged_4)
#     act_1 = Activation('relu')(conv_1)
#     avg_p_1 = AveragePooling2D(strides=2)(act_1)
    
    
#     ##### DENSE BLOCK 3 #####
    
#     bn_1 = BatchNormalization()(avg_p_1)
#     conv_1 = Conv2D(32, (1, 1), padding='same')(bn_1)
#     act_1 = Activation('relu')(conv_1)
#     bn_2 = BatchNormalization()(act_1)
#     conv_2 = Conv2D(8, (3, 3), padding='same')(bn_2)
#     act_2 = Activation('relu')(conv_2)
#     merged_1 =concatenate([act_2, avg_p_1], axis=-1)
    
#     bn_1 = BatchNormalization()(merged_1)
#     conv_1 = Conv2D(32, (1, 1), padding='same')(bn_1)
#     act_1 = Activation('relu')(conv_1)
#     bn_2 = BatchNormalization()(act_1)
#     conv_2 = Conv2D(8, (3, 3), padding='same')(bn_2)
#     act_2 = Activation('relu')(conv_2)
#     merged_2 =concatenate([act_2, merged_1], axis=-1)
    
#     bn_1 = BatchNormalization()(merged_2)
#     conv_1 = Conv2D(32, (1, 1), padding='same')(bn_1)
#     act_1 = Activation('relu')(conv_1)
#     bn_2 = BatchNormalization()(act_1)
#     conv_2 = Conv2D(8, (3, 3), padding='same')(bn_2)
#     act_2 = Activation('relu')(conv_2)
#     merged_3 =concatenate([act_2, merged_2], axis=-1)
    
#     bn_1 = BatchNormalization()(merged_3)
#     conv_1 = Conv2D(32, (1, 1), padding='same')(bn_1)
#     act_1 = Activation('relu')(conv_1)
#     bn_2 = BatchNormalization()(act_1)
#     conv_2 = Conv2D(8, (3, 3), padding='same')(bn_2)
#     act_2 = Activation('relu')(conv_2)
#     merged_4 =concatenate([act_2, merged_3], axis=-1)
    
    ## Dense Layer with GlobalAveragePooling
    
    global_avg_p = GlobalAveragePooling2D()(merged_4)
    denselayer = Dense(100, activation='elu', kernel_regularizer=l2(0.001))(global_avg_p)
    output = Dense(1)(denselayer)
    
    
    model = Model(inputs=[inputs], outputs=[output])
        
    return model

# %%
from keras.utils.training_utils import multi_gpu_model
from keras.optimizers import Adam
from keras import losses

model = DenseNet()
op = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-10, decay=0.008, amsgrad=False)
# model = multi_gpu_model(model, gpus=2)

## loss func : Mean squared error --> mean absoulute error 
model.compile(loss=losses.logcosh, optimizer=op, metrics=['mae'])

# %%
# %%time
hist = model.fit(X_train, y_train, epochs=51, batch_size=24, validation_data=(X_test, y_test), verbose=2)
# Out:
# Train on 448 samples, validate on 112 samples
# Epoch 1/51
#  - 13s - loss: 62.1751 - mean_absolute_error: 62.7893 - val_loss: 17.8207 - val_mean_absolute_error: 18.4016
# Epoch 2/51
#  - 5s - loss: 13.6473 - mean_absolute_error: 14.2535 - val_loss: 13.2520 - val_mean_absolute_error: 13.8681
# Epoch 3/51
#  - 5s - loss: 12.7451 - mean_absolute_error: 13.3586 - val_loss: 9.6046 - val_mean_absolute_error: 10.2037
# Epoch 4/51
#  - 5s - loss: 9.9973 - mean_absolute_error: 10.6075 - val_loss: 47.4907 - val_mean_absolute_error: 48.1196
# Epoch 5/51
#  - 5s - loss: 6.0542 - mean_absolute_error: 6.6356 - val_loss: 12.1767 - val_mean_absolute_error: 12.7784
# Epoch 6/51
#  - 5s - loss: 4.6831 - mean_absolute_error: 5.2609 - val_loss: 25.0924 - val_mean_absolute_error: 25.7217
# Epoch 7/51
#  - 5s - loss: 3.8857 - mean_absolute_error: 4.4589 - val_loss: 10.8969 - val_mean_absolute_error: 11.5206
# Epoch 8/51
#  - 5s - loss: 4.5157 - mean_absolute_error: 5.1049 - val_loss: 5.4410 - val_mean_absolute_error: 6.0328
# Epoch 9/51
#  - 5s - loss: 3.6920 - mean_absolute_error: 4.2643 - val_loss: 82.9266 - val_mean_absolute_error: 83.5604
# Epoch 10/51
#  - 5s - loss: 3.8118 - mean_absolute_error: 4.3805 - val_loss: 7.4022 - val_mean_absolute_error: 8.0231
# Epoch 11/51
#  - 5s - loss: 3.6346 - mean_absolute_error: 4.2077 - val_loss: 7.2431 - val_mean_absolute_error: 7.8622
# Epoch 12/51
#  - 5s - loss: 3.5331 - mean_absolute_error: 4.1172 - val_loss: 2.9424 - val_mean_absolute_error: 3.5197
# Epoch 13/51
#  - 5s - loss: 4.0122 - mean_absolute_error: 4.6016 - val_loss: 2.6026 - val_mean_absolute_error: 3.1569
# Epoch 14/51
#  - 5s - loss: 3.5716 - mean_absolute_error: 4.1475 - val_loss: 6.2450 - val_mean_absolute_error: 6.8613
# Epoch 15/51
#  - 5s - loss: 3.0205 - mean_absolute_error: 3.5857 - val_loss: 2.7516 - val_mean_absolute_error: 3.3210
# Epoch 16/51
#  - 5s - loss: 4.1268 - mean_absolute_error: 4.7112 - val_loss: 4.0067 - val_mean_absolute_error: 4.5932
# Epoch 17/51
#  - 5s - loss: 3.1570 - mean_absolute_error: 3.7340 - val_loss: 2.8064 - val_mean_absolute_error: 3.3715
# Epoch 18/51
#  - 5s - loss: 2.6584 - mean_absolute_error: 3.2107 - val_loss: 5.8483 - val_mean_absolute_error: 6.4596
# Epoch 19/51
#  - 5s - loss: 2.8103 - mean_absolute_error: 3.3789 - val_loss: 7.5429 - val_mean_absolute_error: 8.1696
# Epoch 20/51
#  - 5s - loss: 2.9187 - mean_absolute_error: 3.4830 - val_loss: 4.9098 - val_mean_absolute_error: 5.5158
# Epoch 21/51
#  - 5s - loss: 3.1359 - mean_absolute_error: 3.7013 - val_loss: 3.0500 - val_mean_absolute_error: 3.6242
# Epoch 22/51
#  - 5s - loss: 3.0244 - mean_absolute_error: 3.5931 - val_loss: 5.3073 - val_mean_absolute_error: 5.9376
# Epoch 23/51
#  - 5s - loss: 3.8452 - mean_absolute_error: 4.4291 - val_loss: 2.1867 - val_mean_absolute_error: 2.7311
# Epoch 24/51
#  - 5s - loss: 3.1825 - mean_absolute_error: 3.7483 - val_loss: 4.0004 - val_mean_absolute_error: 4.5861
# Epoch 25/51
#  - 5s - loss: 3.4881 - mean_absolute_error: 4.0708 - val_loss: 1.9235 - val_mean_absolute_error: 2.4664
# Epoch 26/51
#  - 5s - loss: 3.3212 - mean_absolute_error: 3.9031 - val_loss: 2.7875 - val_mean_absolute_error: 3.3279
# Epoch 27/51
#  - 5s - loss: 3.5616 - mean_absolute_error: 4.1321 - val_loss: 2.1260 - val_mean_absolute_error: 2.6615
# Epoch 28/51
#  - 5s - loss: 2.8481 - mean_absolute_error: 3.4161 - val_loss: 2.4235 - val_mean_absolute_error: 2.9940
# Epoch 29/51
#  - 5s - loss: 2.7925 - mean_absolute_error: 3.3473 - val_loss: 8.0259 - val_mean_absolute_error: 8.6662
# Epoch 30/51
#  - 5s - loss: 3.1721 - mean_absolute_error: 3.7462 - val_loss: 2.9733 - val_mean_absolute_error: 3.5402
# Epoch 31/51
#  - 5s - loss: 3.1813 - mean_absolute_error: 3.7516 - val_loss: 3.4509 - val_mean_absolute_error: 4.0447
# Epoch 32/51
#  - 5s - loss: 2.6374 - mean_absolute_error: 3.2056 - val_loss: 2.0328 - val_mean_absolute_error: 2.5635
# Epoch 33/51
#  - 5s - loss: 2.7306 - mean_absolute_error: 3.2944 - val_loss: 2.7895 - val_mean_absolute_error: 3.3563
# Epoch 34/51
#  - 5s - loss: 2.7946 - mean_absolute_error: 3.3663 - val_loss: 2.6966 - val_mean_absolute_error: 3.2412
# Epoch 35/51
#  - 5s - loss: 2.7602 - mean_absolute_error: 3.3243 - val_loss: 2.9775 - val_mean_absolute_error: 3.5455
# Epoch 36/51
#  - 5s - loss: 2.8852 - mean_absolute_error: 3.4547 - val_loss: 2.1865 - val_mean_absolute_error: 2.7477
# Epoch 37/51
#  - 5s - loss: 2.6192 - mean_absolute_error: 3.1822 - val_loss: 4.6607 - val_mean_absolute_error: 5.2760
# Epoch 38/51
#  - 5s - loss: 2.6423 - mean_absolute_error: 3.2078 - val_loss: 1.9367 - val_mean_absolute_error: 2.4777
# Epoch 39/51
#  - 5s - loss: 2.5521 - mean_absolute_error: 3.1065 - val_loss: 2.2719 - val_mean_absolute_error: 2.8218
# Epoch 40/51
#  - 5s - loss: 2.6864 - mean_absolute_error: 3.2487 - val_loss: 4.7674 - val_mean_absolute_error: 5.3860
# Epoch 41/51
#  - 5s - loss: 2.5362 - mean_absolute_error: 3.1042 - val_loss: 2.5812 - val_mean_absolute_error: 3.1133
# Epoch 42/51
#  - 5s - loss: 2.8084 - mean_absolute_error: 3.3843 - val_loss: 1.9034 - val_mean_absolute_error: 2.4378
# Epoch 43/51
#  - 5s - loss: 3.2609 - mean_absolute_error: 3.8415 - val_loss: 8.1898 - val_mean_absolute_error: 8.8310
# Epoch 44/51
#  - 5s - loss: 2.7587 - mean_absolute_error: 3.3235 - val_loss: 2.4503 - val_mean_absolute_error: 3.0213
# Epoch 45/51
#  - 5s - loss: 2.8082 - mean_absolute_error: 3.3863 - val_loss: 2.9638 - val_mean_absolute_error: 3.5535
# Epoch 46/51
#  - 5s - loss: 2.6954 - mean_absolute_error: 3.2682 - val_loss: 1.8793 - val_mean_absolute_error: 2.4345
# Epoch 47/51
#  - 5s - loss: 2.6630 - mean_absolute_error: 3.2224 - val_loss: 4.8355 - val_mean_absolute_error: 5.4369
# Epoch 48/51
#  - 5s - loss: 2.7380 - mean_absolute_error: 3.2981 - val_loss: 2.3496 - val_mean_absolute_error: 2.9236
# Epoch 49/51
#  - 5s - loss: 3.0917 - mean_absolute_error: 3.6598 - val_loss: 4.7175 - val_mean_absolute_error: 5.3322
# Epoch 50/51
#  - 5s - loss: 2.3962 - mean_absolute_error: 2.9556 - val_loss: 1.8663 - val_mean_absolute_error: 2.4124
# Epoch 51/51
#  - 5s - loss: 2.6920 - mean_absolute_error: 3.2555 - val_loss: 1.8135 - val_mean_absolute_error: 2.3618
# CPU times: user 2min 44s, sys: 1min 6s, total: 3min 50s
# Wall time: 4min 11s

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(9,9))
plt.plot(hist.history["mean_absolute_error"])
plt.plot(hist.history["val_mean_absolute_error"])
plt.show()

# %%
pred = model.predict(X_test)
for i, j in zip(pred, y_test):
    print("prediction : {}, Truth : {} ".format(i, j))
# Out:
# prediction : [96.99013], Truth : 95.69
# prediction : [126.64892], Truth : 124.51
# prediction : [126.520874], Truth : 125.38
# prediction : [94.710945], Truth : 92.77
# prediction : [115.58733], Truth : 125.53
# prediction : [97.101395], Truth : 91.66
# prediction : [126.84363], Truth : 128.98
# prediction : [113.69842], Truth : 120.29
# prediction : [123.84396], Truth : 122.88
# prediction : [96.65738], Truth : 93.89
# prediction : [124.48039], Truth : 129.03
# prediction : [127.08376], Truth : 128.82
# prediction : [126.6682], Truth : 126.05
# prediction : [126.78036], Truth : 128.0
# prediction : [121.111786], Truth : 120.34
# prediction : [96.89235], Truth : 96.27
# prediction : [124.79469], Truth : 124.27
# prediction : [125.384094], Truth : 120.82
# prediction : [123.15028], Truth : 121.72
# prediction : [95.34826], Truth : 96.7
# prediction : [95.05395], Truth : 91.35
# prediction : [94.84937], Truth : 92.98
# prediction : [94.381454], Truth : 99.25
# prediction : [95.061295], Truth : 99.67
# prediction : [96.82121], Truth : 91.46
# prediction : [94.90587], Truth : 94.13
# prediction : [97.08717], Truth : 95.26
# prediction : [94.24173], Truth : 98.18
# prediction : [95.04561], Truth : 97.32
# prediction : [95.3512], Truth : 95.76
# prediction : [95.22809], Truth : 92.1
# prediction : [94.747986], Truth : 95.46
# prediction : [96.59431], Truth : 99.25
# prediction : [97.31259], Truth : 94.42
# prediction : [95.23714], Truth : 90.76
# prediction : [96.99089], Truth : 96.26
# prediction : [94.25486], Truth : 93.9
# prediction : [95.22347], Truth : 91.3
# prediction : [96.4864], Truth : 94.84
# prediction : [105.94202], Truth : 102.3
# prediction : [104.61336], Truth : 100.68
# prediction : [104.84524], Truth : 101.86
# prediction : [107.21411], Truth : 107.83
# prediction : [107.32732], Truth : 109.35
# prediction : [105.07995], Truth : 101.69
# prediction : [105.02583], Truth : 102.71
# prediction : [105.64191], Truth : 109.71
# prediction : [105.25322], Truth : 106.77
# prediction : [104.9555], Truth : 104.84
# prediction : [105.934204], Truth : 107.62
# prediction : [105.76719], Truth : 106.4
# prediction : [105.62054], Truth : 101.2
# prediction : [105.468765], Truth : 108.11
# prediction : [107.72856], Truth : 109.28
# prediction : [108.14666], Truth : 105.45
# prediction : [104.92568], Truth : 103.83
# prediction : [105.21535], Truth : 100.69
# prediction : [106.167336], Truth : 108.17
# prediction : [107.841194], Truth : 103.13
# prediction : [105.449135], Truth : 102.35
# prediction : [107.26667], Truth : 102.94
# prediction : [103.87693], Truth : 102.48
# prediction : [113.47989], Truth : 116.01
# prediction : [115.74674], Truth : 112.6
# prediction : [114.22382], Truth : 111.9
# prediction : [114.29386], Truth : 113.76
# prediction : [115.651436], Truth : 110.68
# prediction : [114.73796], Truth : 111.41
# prediction : [112.430466], Truth : 111.53
# prediction : [115.02127], Truth : 116.87
# prediction : [117.636856], Truth : 118.62
# prediction : [115.351425], Truth : 118.41
# prediction : [115.2837], Truth : 115.68
# prediction : [114.742714], Truth : 116.06
# prediction : [118.87845], Truth : 119.09
# prediction : [115.96824], Truth : 113.5
# prediction : [116.184135], Truth : 116.81
# prediction : [113.635605], Truth : 110.6
# prediction : [114.61356], Truth : 114.16
# prediction : [119.11535], Truth : 119.24
# prediction : [115.011246], Truth : 114.28
# prediction : [113.46518], Truth : 111.68
# prediction : [115.54704], Truth : 112.12
# prediction : [112.08882], Truth : 113.85
# prediction : [116.50476], Truth : 118.3
# prediction : [115.22416], Truth : 114.92
# prediction : [117.18801], Truth : 113.62
# prediction : [116.86416], Truth : 115.11
# prediction : [115.61611], Truth : 119.15
# prediction : [116.307785], Truth : 114.0
# prediction : [116.6495], Truth : 111.98
# prediction : [115.474945], Truth : 115.37
# prediction : [112.49635], Truth : 114.65
# prediction : [116.30888], Truth : 114.11
# prediction : [126.11232], Truth : 129.89
# prediction : [123.83511], Truth : 129.09
# prediction : [126.67429], Truth : 127.6
# prediction : [125.059975], Truth : 121.71
# prediction : [125.8857], Truth : 121.08
# prediction : [126.55739], Truth : 126.14
# prediction : [126.30019], Truth : 127.14
# prediction : [125.77982], Truth : 122.39
# prediction : [123.86984], Truth : 126.09
# prediction : [124.23951], Truth : 124.45
# prediction : [126.064186], Truth : 123.79
# prediction : [126.75264], Truth : 124.41
# prediction : [125.3569], Truth : 126.34
# prediction : [124.8055], Truth : 121.83
# prediction : [125.671974], Truth : 122.98
# prediction : [125.24762], Truth : 125.12
# prediction : [127.44983], Truth : 125.6
# prediction : [120.64941], Truth : 123.08

# %%
from keras.models import load_model
import pickle
import h5py

model.save('DenseNet_0725_51Epochs_logcosh.hdf5')
del model
